# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')

text = "Lionel Messi is widely regarded as one of the greatest footballers in history, known for his extraordinary dribbling, vision, and goal-scoring ability. Rising to fame at FC Barcelona, he broke numerous records and won multiple Ballon d’Or awards, becoming a symbol of consistency and creativity on the field. His career reached a historic peak when he led Argentina to victory in the 2022 FIFA World Cup, showcasing leadership and resilience while inspiring millions of fans around the world."
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
words = word_tokenize(text)

# loading stop words
stop_words = set(stopwords.words('english'))

# %%
# removing stopwords

filtered_words = [word for word in words if word not in stop_words]
print(filtered_words)
# Out:
# ['Lionel', 'Messi', 'widely', 'regarded', 'one', 'greatest', 'footballers', 'history', ',', 'known', 'extraordinary', 'dribbling', ',', 'vision', ',', 'goal-scoring', 'ability', '.', 'Rising', 'fame', 'FC', 'Barcelona', ',', 'broke', 'numerous', 'records', 'multiple', 'Ballon', '’', 'Or', 'awards', ',', 'becoming', 'symbol', 'consistency', 'creativity', 'field', '.', 'His', 'career', 'reached', 'historic', 'peak', 'led', 'Argentina', 'victory', '2022', 'FIFA', 'World', 'Cup', ',', 'showcasing', 'leadership', 'resilience', 'inspiring', 'millions', 'fans', 'around', 'world', '.']

# %% [markdown]
# ## using spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

text = "Lionel Messi is widely regarded as one of the greatest footballers in history, known for his extraordinary dribbling, vision, and goal-scoring ability. Rising to fame at FC Barcelona, he broke numerous records and won multiple Ballon d’Or awards, becoming a symbol of consistency and creativity on the field. His career reached a historic peak when he led Argentina to victory in the 2022 FIFA World Cup, showcasing leadership and resilience while inspiring millions of fans around the world."

doc = nlp(text)

# %%
stop_words = [token.text for token in doc if not token.is_stop]
print(stop_words)
# Out:
# ['Lionel', 'Messi', 'widely', 'regarded', 'greatest', 'footballers', 'history', ',', 'known', 'extraordinary', 'dribbling', ',', 'vision', ',', 'goal', '-', 'scoring', 'ability', '.', 'Rising', 'fame', 'FC', 'Barcelona', ',', 'broke', 'numerous', 'records', 'won', 'multiple', 'Ballon', 'd’Or', 'awards', ',', 'symbol', 'consistency', 'creativity', 'field', '.', 'career', 'reached', 'historic', 'peak', 'led', 'Argentina', 'victory', '2022', 'FIFA', 'World', 'Cup', ',', 'showcasing', 'leadership', 'resilience', 'inspiring', 'millions', 'fans', 'world', '.']

# %% [markdown]
# ### if we want to return in string

# %%
result = " ".join(filtered_words)
print(result)
# Out:
# Lionel Messi widely regarded one greatest footballers history , known extraordinary dribbling , vision , goal-scoring ability . Rising fame FC Barcelona , broke numerous records multiple Ballon ’ Or awards , becoming symbol consistency creativity field . His career reached historic peak led Argentina victory 2022 FIFA World Cup , showcasing leadership resilience inspiring millions fans around world .

# %%
text = "Iron Man, also known as Tony Stark, is one of the central heroes in the Avengers, blending genius-level engineering with bold, often sarcastic leadership. Using his advanced armored suits, he protects Earth from powerful threats while constantly evolving his technology to face new challenges. Beyond the action, his journey in the Avengers highlights personal growth — from a self-focused inventor to a hero willing to sacrifice everything for the greater good, making him one of the most compelling figures in the team."

doc = nlp(text)
filter = [token.text for token in doc if not token.is_stop]

print(" ".join(filter))
# Out:
# Iron Man , known Tony Stark , central heroes Avengers , blending genius - level engineering bold , sarcastic leadership . advanced armored suits , protects Earth powerful threats constantly evolving technology face new challenges . action , journey Avengers highlights personal growth — self - focused inventor hero willing sacrifice greater good , making compelling figures team .

# %% [markdown]
# # stop word removal on datasets

# %%
import pandas as pd
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv(r"C:\Users\HP\PycharmProjects\JupyterProject\Downloads\spam.csv",encoding="latin-1")

df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
def remove_stopwords(text):
    doc = nlp(text)
    filtered_tokens = [
        token.text
        for token in doc
        if not token.is_stop and not token.is_punct
    ]
    return " ".join(filtered_tokens)

# %%
df["v2_new"] = df["v2"].apply(remove_stopwords)

# %%
print(df[["v2", "v2_new"]].head())
# Out:
#                                                   v2  \
# 0  Go until jurong point, crazy.. Available only ...
# 1                      Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  U dun say so early hor... U c already then say...
# 4  Nah I don't think he goes to usf, he lives aro...
#
#                                               v2_new
# 0  jurong point crazy Available bugis n great wor...
# 1                            Ok lar Joking wif u oni
# 2  Free entry 2 wkly comp win FA Cup final tkts 2...
# 3                                U dun early hor U c
# 4                           Nah think goes usf lives
